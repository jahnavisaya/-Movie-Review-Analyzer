# %% [markdown]
# ## MOVIE_REVIEWS _DATASET
#
# we have movie reviews written by people and we want to know whether a review is positive or negative
# we want to build a classifier such that given a review can predict it is positive or negative

# %%
from nltk.corpus import movie_reviews

# %%
import nltk
nltk.download('movie_reviews')
# Out:
# [nltk_data] Downloading package movie_reviews to C:\Users\saya
# [nltk_data]     jahnavi\AppData\Roaming\nltk_data...
# [nltk_data]   Package movie_reviews is already up-to-date!
# True

# %%
movie_reviews.categories()
# Out:
# ['neg', 'pos']

# %%
movie_reviews.fileids()
# Out:
# ['neg/cv000_29416.txt',
#  'neg/cv001_19502.txt',
#  'neg/cv002_17424.txt',
#  'neg/cv003_12683.txt',
#  'neg/cv004_12641.txt',
#  'neg/cv005_29357.txt',
#  'neg/cv006_17022.txt',
#  'neg/cv007_4992.txt',
#  'neg/cv008_29326.txt',
#  'neg/cv009_29417.txt',
#  'neg/cv010_29063.txt',
#  'neg/cv011_13044.txt',
#  'neg/cv012_29411.txt',
#  'neg/cv013_10494.txt',
#  'neg/cv014_15600.txt',
#  'neg/cv015_29356.txt',
#  'neg/cv016_4348.txt',
#  'neg/cv017_23487.txt',
#  'neg/cv018_21672.txt',
#  'neg/cv019_16117.txt',
#  'neg/cv020_9234.txt',
#  'neg/cv021_17313.txt',
#  'neg/cv022_14227.txt',
#  'neg/cv023_13847.txt',
#  'neg/cv024_7033.txt',
#  'neg/cv025_29825.txt',
#  'neg/cv026_29229.txt',
#  'neg/cv027_26270.txt',
#  'neg/cv028_26964.txt',
#  'neg/cv029_19943.txt',
#  'neg/cv030_22893.txt',
#  'neg/cv031_19540.txt',
#  'neg/cv032_23718.txt',
#  'neg/cv033_25680.txt',
#  'neg/cv034_29446.txt',
#  'neg/cv035_3343.txt',
#  'neg/cv036_18385.txt',
#  'neg/cv037_19798.txt',
# ...

# %%
len(movie_reviews.fileids()) # we have 2000 reviews in total 1000 negative 1000 positive
# Out:
# 2000

# %%
# to get only neg review category

movie_reviews.fileids('neg')
# Out:
# ['neg/cv000_29416.txt',
#  'neg/cv001_19502.txt',
#  'neg/cv002_17424.txt',
#  'neg/cv003_12683.txt',
#  'neg/cv004_12641.txt',
#  'neg/cv005_29357.txt',
#  'neg/cv006_17022.txt',
#  'neg/cv007_4992.txt',
#  'neg/cv008_29326.txt',
#  'neg/cv009_29417.txt',
#  'neg/cv010_29063.txt',
#  'neg/cv011_13044.txt',
#  'neg/cv012_29411.txt',
#  'neg/cv013_10494.txt',
#  'neg/cv014_15600.txt',
#  'neg/cv015_29356.txt',
#  'neg/cv016_4348.txt',
#  'neg/cv017_23487.txt',
#  'neg/cv018_21672.txt',
#  'neg/cv019_16117.txt',
#  'neg/cv020_9234.txt',
#  'neg/cv021_17313.txt',
#  'neg/cv022_14227.txt',
#  'neg/cv023_13847.txt',
#  'neg/cv024_7033.txt',
#  'neg/cv025_29825.txt',
#  'neg/cv026_29229.txt',
#  'neg/cv027_26270.txt',
#  'neg/cv028_26964.txt',
#  'neg/cv029_19943.txt',
#  'neg/cv030_22893.txt',
#  'neg/cv031_19540.txt',
#  'neg/cv032_23718.txt',
#  'neg/cv033_25680.txt',
#  'neg/cv034_29446.txt',
#  'neg/cv035_3343.txt',
#  'neg/cv036_18385.txt',
#  'neg/cv037_19798.txt',
# ...

# %%
movie_reviews.fileids('pos')
# Out:
# ['pos/cv000_29590.txt',
#  'pos/cv001_18431.txt',
#  'pos/cv002_15918.txt',
#  'pos/cv003_11664.txt',
#  'pos/cv004_11636.txt',
#  'pos/cv005_29443.txt',
#  'pos/cv006_15448.txt',
#  'pos/cv007_4968.txt',
#  'pos/cv008_29435.txt',
#  'pos/cv009_29592.txt',
#  'pos/cv010_29198.txt',
#  'pos/cv011_12166.txt',
#  'pos/cv012_29576.txt',
#  'pos/cv013_10159.txt',
#  'pos/cv014_13924.txt',
#  'pos/cv015_29439.txt',
#  'pos/cv016_4659.txt',
#  'pos/cv017_22464.txt',
#  'pos/cv018_20137.txt',
#  'pos/cv019_14482.txt',
#  'pos/cv020_8825.txt',
#  'pos/cv021_15838.txt',
#  'pos/cv022_12864.txt',
#  'pos/cv023_12672.txt',
#  'pos/cv024_6778.txt',
#  'pos/cv025_3108.txt',
#  'pos/cv026_29325.txt',
#  'pos/cv027_25219.txt',
#  'pos/cv028_26746.txt',
#  'pos/cv029_18643.txt',
#  'pos/cv030_21593.txt',
#  'pos/cv031_18452.txt',
#  'pos/cv032_22550.txt',
#  'pos/cv033_24444.txt',
#  'pos/cv034_29647.txt',
#  'pos/cv035_3954.txt',
#  'pos/cv036_16831.txt',
#  'pos/cv037_18510.txt',
# ...

# %%
movie_reviews.words(movie_reviews.fileids()[5]) # to access words written with a review
# Out:
# ['capsule', ':', 'in', '2176', 'on', 'the', 'planet', ...]

# %% [markdown]
# now for the 2000 data, creating an array and in this array we will store words and along with the words , we will store category i.e, a tuple for each document. so that is how array are arranged . so we will have 2000 sized array

# %%
documents = []
for category in movie_reviews.categories():
    for fileid in movie_reviews.fileids(category):
        documents.append((movie_reviews.words(fileid), category))
documents[0:5]
# Out:
# [(['plot', ':', 'two', 'teen', 'couples', 'go', 'to', ...], 'neg'),
#  (['the', 'happy', 'bastard', "'", 's', 'quick', 'movie', ...], 'neg'),
#  (['it', 'is', 'movies', 'like', 'these', 'that', 'make', ...], 'neg'),
#  (['"', 'quest', 'for', 'camelot', '"', 'is', 'warner', ...], 'neg'),
#  (['synopsis', ':', 'a', 'mentally', 'unstable', 'man', ...], 'neg')]

# %%
# our document array is ready

# %%
# lets shuffle them then pos and neg mixed up so split used better for train and test data

import random
random.shuffle(documents)
documents[0:5]
# Out:
# [(['one', 'of', 'the', 'biggest', 'cliches', 'of', 'any', ...], 'pos'),
#  (['i', 'heard', 'actor', 'skeet', 'ulrich', ...], 'neg'),
#  (['jonathan', 'demme', "'", 's', '_beloved_', ',', ...], 'pos'),
#  (['with', 'a', 'team', 'of', '200', 'graphic', ...], 'pos'),
#  (['it', "'", 's', 'wednesday', ',', 'march', '27', ',', ...], 'pos')]

# %%
# now we want to clean each of this text i.e remove stop words along with that do lemmatization
# lets write a fucntion whic we use for cleaning

from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetlemmatizer()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 5
#       1 # now we want to clean each of this text i.e remove stop words along with that do lemmatization
#       2 # lets write a fucntion whic we use for cleaning
#       4 from nltk.stem import WordNetLemmatizer
# ----> 5 lemmatizer = WordNetlemmatizer()
#
# NameError: name 'WordNetlemmatizer' is not defined

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

# %%
from nltk.corpus import wordnet
def get_simple_pos(tag):
    
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

# %%
from nltk import pos_tag
w = "better"                            ## EXAMPLE ##
pos_tag([w])             # we need to pass pos_tag to array and not to single word
# Out:
# [('better', 'RBR')]

# %%
from nltk.corpus import stopwords
import string
stops = set(stopwords.words('english'))
punctuations = list(string.punctuation)
stops.update(punctuations)
stops,punctuations
# Out:
# ({'!',
#   '"',
#   '#',
#   '$',
#   '%',
#   '&',
#   "'",
#   '(',
#   ')',
#   '*',
#   '+',
#   ',',
#   '-',
#   '.',
#   '/',
#   ':',
#   ';',
#   '<',
#   '=',
#   '>',
#   '?',
#   '@',
#   '[',
#   '\\',
#   ']',
#   '^',
#   '_',
#   '`',
#   'a',
#   'about',
#   'above',
#   'after',
#   'again',
#   'against',
#   'ain',
#   'all',
#   'am',
#   'an',
#   'and',
#   'any',
#   'are',
#   'aren',
#   "aren't",
#   'as',
#   'at',
#   'be',
#   'because',
#   'been',
#   'before',
#   'being',
#   'below',
#   'between',
#   'both',
#   'but',
#   'by',
#   'can',
#   'couldn',
#   "couldn't",
#   'd',
#   'did',
#   'didn',
#   "didn't",
#   'do',
#   'does',
#   'doesn',
#   "doesn't",
#   'doing',
#   'don',
#   "don't",
#   'down',
#   'during',
#   'each',
#   'few',
#   'for',
#   'from',
#   'further',
#   'had',
#   'hadn',
#   "hadn't",
#   'has',
#   'hasn',
#   "hasn't",
#   'have',
#   'haven',
#   "haven't",
#   'having',
#   'he',
#   'her',
#   'here',
# ...

# %%
from nltk.corpus import stopwords
import string
stops = set(stopwords.words('english'))
punctuations = list(string.punctuation)
stops.update(punctuations)
stops, string.punctuation
# Out:
# ({'!',
#   '"',
#   '#',
#   '$',
#   '%',
#   '&',
#   "'",
#   '(',
#   ')',
#   '*',
#   '+',
#   ',',
#   '-',
#   '.',
#   '/',
#   ':',
#   ';',
#   '<',
#   '=',
#   '>',
#   '?',
#   '@',
#   '[',
#   '\\',
#   ']',
#   '^',
#   '_',
#   '`',
#   'a',
#   'about',
#   'above',
#   'after',
#   'again',
#   'against',
#   'ain',
#   'all',
#   'am',
#   'an',
#   'and',
#   'any',
#   'are',
#   'aren',
#   "aren't",
#   'as',
#   'at',
#   'be',
#   'because',
#   'been',
#   'before',
#   'being',
#   'below',
#   'between',
#   'both',
#   'but',
#   'by',
#   'can',
#   'couldn',
#   "couldn't",
#   'd',
#   'did',
#   'didn',
#   "didn't",
#   'do',
#   'does',
#   'doesn',
#   "doesn't",
#   'doing',
#   'don',
#   "don't",
#   'down',
#   'during',
#   'each',
#   'few',
#   'for',
#   'from',
#   'further',
#   'had',
#   'hadn',
#   "hadn't",
#   'has',
#   'hasn',
#   "hasn't",
#   'have',
#   'haven',
#   "haven't",
#   'having',
#   'he',
#   'her',
#   'here',
# ...

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# Download necessary NLTK data
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')

# Initialize the lemmatizer
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\saya
# [nltk_data]     jahnavi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to C:\Users\saya
# [nltk_data]     jahnavi\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\saya
# [nltk_data]     jahnavi\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
def clean_review(words):
    output_words = []
    for w in words:
        if w.lower() not in stops:
            pos = pos_tag([w])
            clean_word = lemmatizer.lemmatize(w, pos = get_simple_pos(pos[0][1]))
            output_words.append(clean_word.lower())
    return output_words

# %%
# lets go through documents and clean

documents = [(clean_review(document), category) for document, category in documents]

# %%
documents[0]
# Out:
# (['one',
#   'big',
#   'cliche',
#   'serial',
#   'killer',
#   'film',
#   'also',
#   'one',
#   'believable',
#   'know',
#   'one',
#   'detective',
#   'look',
#   'wall',
#   'picture',
#   'police',
#   'information',
#   'suddenly',
#   'spot',
#   'clue',
#   'reveals',
#   'killer',
#   'sure',
#   'use',
#   'reason',
#   'always',
#   'fun',
#   'watch',
#   'cliche',
#   'pretty',
#   'much',
#   'describes',
#   'level',
#   'kiss',
#   'girl',
#   'work',
#   'overuse',
#   'always',
#   'fun',
#   'one',
#   'personal',
#   'rule',
#   'watch',
#   'film',
#   'original',
#   'film',
#   'go',
#   'around',
#   'give',
#   'story',
#   'rule',
#   'applies',
#   'highly',
#   'kiss',
#   'girl',
#   'something',
#   'psychologically',
#   'stimulate',
#   'well',
#   'craft',
#   'serial',
#   'killer',
#   'movie',
#   'kiss',
#   'girl',
#   'certainly',
#   'well',
#   'make',
#   'however',
#   'whole',
#   'film',
#   'scream',
#   'unoriginality',
# ...

# %% [markdown]
# ## Building Feature set

# %%
training_documents = documents[0:1500]
testing_documents = documents[1500:]

# %%
 # with this cleaned data lets create an array containing all the words
# creatuing of feature set should be done on the training data not on the testing data
    
all_words = []
for doc in training_documents:
    all_words += doc[0] # doc is a tuple with zeri=oth entry words and first entry category now we combined all words

# %%
import nltk

# %%
nltk.FreqDist(all_words)  # this frequency disdistribution object
# Out:
# FreqDist({'film': 8429, 'movie': 5086, 'one': 4507, 'make': 3283, 'character': 2969, 'like': 2955, 'get': 2800, 'see': 2316, 'go': 2283, 'time': 2273, ...})

# %%
freq = nltk.FreqDist(all_words)  # this frequency disdistribution object
freq.most_common(15) # this top 15 words which occur commonly
# Out:
# [('film', 8429),
#  ('movie', 5086),
#  ('one', 4507),
#  ('make', 3283),
#  ('character', 2969),
#  ('like', 2955),
#  ('get', 2800),
#  ('see', 2316),
#  ('go', 2283),
#  ('time', 2273),
#  ('well', 2139),
#  ('scene', 2046),
#  ('even', 1988),
#  ('good', 1861),
#  ('story', 1753)]

# %%
freq = nltk.FreqDist(all_words)  # this frequency disdistribution object
freq.most_common(3000) # this top 3000 words which occur commonly
# Out:
# [('film', 8429),
#  ('movie', 5086),
#  ('one', 4507),
#  ('make', 3283),
#  ('character', 2969),
#  ('like', 2955),
#  ('get', 2800),
#  ('see', 2316),
#  ('go', 2283),
#  ('time', 2273),
#  ('well', 2139),
#  ('scene', 2046),
#  ('even', 1988),
#  ('good', 1861),
#  ('story', 1753),
#  ('take', 1646),
#  ('would', 1595),
#  ('much', 1573),
#  ('also', 1504),
#  ('give', 1493),
#  ('come', 1488),
#  ('life', 1473),
#  ('bad', 1472),
#  ('two', 1459),
#  ('seem', 1420),
#  ('--', 1413),
#  ('way', 1406),
#  ('look', 1398),
#  ('end', 1376),
#  ('know', 1365),
#  ('first', 1351),
#  ('year', 1324),
#  ('work', 1314),
#  ('thing', 1228),
#  ('plot', 1203),
#  ('say', 1202),
#  ('play', 1199),
#  ('show', 1172),
#  ('little', 1159),
#  ('really', 1141),
#  ('people', 1108),
#  ('could', 1098),
#  ('u', 1095),
#  ('man', 1060),
#  ('love', 1056),
#  ('never', 1037),
#  ('star', 1033),
#  ('best', 1028),
#  ('performance', 1021),
#  ('try', 1009),
#  ('director', 1005),
#  ('new', 990),
# ...

# %%
# now we dont require the frequency only the word

freq = nltk.FreqDist(all_words)
common = freq.most_common(3000)
features = [i[0] for i in common ]

# %%
features
# Out:
# ['film',
#  'movie',
#  'one',
#  'make',
#  'character',
#  'like',
#  'get',
#  'see',
#  'go',
#  'time',
#  'well',
#  'scene',
#  'even',
#  'good',
#  'story',
#  'take',
#  'would',
#  'much',
#  'also',
#  'give',
#  'come',
#  'life',
#  'bad',
#  'two',
#  'seem',
#  '--',
#  'way',
#  'look',
#  'end',
#  'know',
#  'first',
#  'year',
#  'work',
#  'thing',
#  'plot',
#  'say',
#  'play',
#  'show',
#  'little',
#  'really',
#  'people',
#  'could',
#  'u',
#  'man',
#  'love',
#  'never',
#  'star',
#  'best',
#  'performance',
#  'try',
#  'director',
#  'new',
#  'big',
#  'great',
#  'action',
#  'want',
#  'actor',
#  'many',
#  'watch',
#  'find',
#  'role',
#  'think',
#  'act',
#  'audience',
#  'another',
#  'back',
#  'day',
#  'turn',
#  'set',
#  'world',
#  'feel',
#  'something',
#  'however',
#  'old',
#  'still',
#  'use',
#  'begin',
#  'every',
#  'guy',
#  'part',
#  'comedy',
#  'though',
#  'point',
#  'interest',
#  'real',
#  'cast',
#  'enough',
# ...

# %%
# now we know our features for each document we want to create dictionary where this dictionary will have { right : True or right: False} whether it comes or not


documents [0]
# Out:
# (['one',
#   'big',
#   'cliche',
#   'serial',
#   'killer',
#   'film',
#   'also',
#   'one',
#   'believable',
#   'know',
#   'one',
#   'detective',
#   'look',
#   'wall',
#   'picture',
#   'police',
#   'information',
#   'suddenly',
#   'spot',
#   'clue',
#   'reveals',
#   'killer',
#   'sure',
#   'use',
#   'reason',
#   'always',
#   'fun',
#   'watch',
#   'cliche',
#   'pretty',
#   'much',
#   'describes',
#   'level',
#   'kiss',
#   'girl',
#   'work',
#   'overuse',
#   'always',
#   'fun',
#   'one',
#   'personal',
#   'rule',
#   'watch',
#   'film',
#   'original',
#   'film',
#   'go',
#   'around',
#   'give',
#   'story',
#   'rule',
#   'applies',
#   'highly',
#   'kiss',
#   'girl',
#   'something',
#   'psychologically',
#   'stimulate',
#   'well',
#   'craft',
#   'serial',
#   'killer',
#   'movie',
#   'kiss',
#   'girl',
#   'certainly',
#   'well',
#   'make',
#   'however',
#   'whole',
#   'film',
#   'scream',
#   'unoriginality',
# ...

# %%
get_feature_dict(training_documents[0][0])
get_feature_dict
# Out:
# <function __main__.get_feature_dict(words)>

# %%
training_documents[0][0]
# Out:
# ['one',
#  'big',
#  'cliche',
#  'serial',
#  'killer',
#  'film',
#  'also',
#  'one',
#  'believable',
#  'know',
#  'one',
#  'detective',
#  'look',
#  'wall',
#  'picture',
#  'police',
#  'information',
#  'suddenly',
#  'spot',
#  'clue',
#  'reveals',
#  'killer',
#  'sure',
#  'use',
#  'reason',
#  'always',
#  'fun',
#  'watch',
#  'cliche',
#  'pretty',
#  'much',
#  'describes',
#  'level',
#  'kiss',
#  'girl',
#  'work',
#  'overuse',
#  'always',
#  'fun',
#  'one',
#  'personal',
#  'rule',
#  'watch',
#  'film',
#  'original',
#  'film',
#  'go',
#  'around',
#  'give',
#  'story',
#  'rule',
#  'applies',
#  'highly',
#  'kiss',
#  'girl',
#  'something',
#  'psychologically',
#  'stimulate',
#  'well',
#  'craft',
#  'serial',
#  'killer',
#  'movie',
#  'kiss',
#  'girl',
#  'certainly',
#  'well',
#  'make',
#  'however',
#  'whole',
#  'film',
#  'scream',
#  'unoriginality',
#  'relies',
#  'power',
#  'actor',
#  'technical',
#  'detail',
#  'pull',
# ...

# %%
def get_feature_dict(words):
    current_features = {}
    words_set = set(words)
    for w in features:
        current_features[w] = w in words_set
    return current_features

# %%
features
# Out:
# ['film',
#  'movie',
#  'one',
#  'make',
#  'character',
#  'like',
#  'get',
#  'see',
#  'go',
#  'time',
#  'well',
#  'scene',
#  'even',
#  'good',
#  'story',
#  'take',
#  'would',
#  'much',
#  'also',
#  'give',
#  'come',
#  'life',
#  'bad',
#  'two',
#  'seem',
#  '--',
#  'way',
#  'look',
#  'end',
#  'know',
#  'first',
#  'year',
#  'work',
#  'thing',
#  'plot',
#  'say',
#  'play',
#  'show',
#  'little',
#  'really',
#  'people',
#  'could',
#  'u',
#  'man',
#  'love',
#  'never',
#  'star',
#  'best',
#  'performance',
#  'try',
#  'director',
#  'new',
#  'big',
#  'great',
#  'action',
#  'want',
#  'actor',
#  'many',
#  'watch',
#  'find',
#  'role',
#  'think',
#  'act',
#  'audience',
#  'another',
#  'back',
#  'day',
#  'turn',
#  'set',
#  'world',
#  'feel',
#  'something',
#  'however',
#  'old',
#  'still',
#  'use',
#  'begin',
#  'every',
#  'guy',
#  'part',
#  'comedy',
#  'though',
#  'point',
#  'interest',
#  'real',
#  'cast',
#  'enough',
# ...

# %%
output = get_feature_dict(training_documents[0][0])
output
# Out:
# {'film': True,
#  'movie': True,
#  'one': True,
#  'make': True,
#  'character': True,
#  'like': True,
#  'get': True,
#  'see': True,
#  'go': True,
#  'time': False,
#  'well': True,
#  'scene': True,
#  'even': True,
#  'good': True,
#  'story': True,
#  'take': True,
#  'would': True,
#  'much': True,
#  'also': True,
#  'give': True,
#  'come': True,
#  'life': False,
#  'bad': False,
#  'two': True,
#  'seem': True,
#  '--': True,
#  'way': True,
#  'look': True,
#  'end': True,
#  'know': True,
#  'first': True,
#  'year': True,
#  'work': True,
#  'thing': False,
#  'plot': True,
#  'say': True,
#  'play': False,
#  'show': True,
#  'little': False,
#  'really': True,
#  'people': True,
#  'could': True,
#  'u': True,
#  'man': False,
#  'love': True,
#  'never': True,
#  'star': True,
#  'best': True,
#  'performance': True,
#  'try': True,
#  'director': True,
#  'new': False,
#  'big': True,
#  'great': False,
#  'action': False,
#  'want': False,
#  'actor': True,
# ...

# %%
training_data = [(get_feature_dict(doc), category)for doc, category in training_documents]
testing_data = [(get_feature_dict(doc), category)for doc, category in training_documents]

# %%
training_data[0]
# Out:
# ({'film': True,
#   'movie': True,
#   'one': True,
#   'make': True,
#   'character': True,
#   'like': True,
#   'get': True,
#   'see': True,
#   'go': True,
#   'time': False,
#   'well': True,
#   'scene': True,
#   'even': True,
#   'good': True,
#   'story': True,
#   'take': True,
#   'would': True,
#   'much': True,
#   'also': True,
#   'give': True,
#   'come': True,
#   'life': False,
#   'bad': False,
#   'two': True,
#   'seem': True,
#   '--': True,
#   'way': True,
#   'look': True,
#   'end': True,
#   'know': True,
#   'first': True,
#   'year': True,
#   'work': True,
#   'thing': False,
#   'plot': True,
#   'say': True,
#   'play': False,
#   'show': True,
#   'little': False,
#   'really': True,
#   'people': True,
#   'could': True,
#   'u': True,
#   'man': False,
#   'love': True,
#   'never': True,
#   'star': True,
#   'best': True,
#   'performance': True,
#   'try': True,
#   'director': True,
#   'new': False,
#   'big': True,
#   'great': False,
# ...

# %% [markdown]
# ## Classification Using NLTK Naive Bayes Classifier

# %%
# NLTK classifier require data in format of array of tuples where each tuple has a dictionarywhich is basically feature and feature value & category that particular datapoint is part of
# i,e. array of tuples, where each tuple has dictionary pf features and category

# %%
from nltk import NaiveBayesClassifier

# %%
# from nltk.classify.util import accuracy as nltk_accuracy

# %%
classifier = NaiveBayesClassifier.train(training_data)

# %%
nltk.classify.accuracy(classifier, testing_data) # this gives accuracy of this naive bayesclassifier on the testing data
# Out:
# 0.8746666666666667

# %%
classifier.show_most_informative_features(15)
# Out:
# Most Informative Features
#                ludicrous = True              neg : pos    =     20.1 : 1.0
#                stupidity = True              neg : pos    =     16.7 : 1.0
#                    damon = True              pos : neg    =     12.7 : 1.0
#                   seagal = True              neg : pos    =     11.9 : 1.0
#              outstanding = True              pos : neg    =     10.8 : 1.0
#                   prinze = True              neg : pos    =      8.5 : 1.0
#                   random = True              neg : pos    =      8.3 : 1.0
#                  idiotic = True              neg : pos    =      7.7 : 1.0
#                 religion = True              pos : neg    =      6.9 : 1.0
#                    anger = True              pos : neg    =      6.6 : 1.0
#                   belief = True              pos : neg    =      6.6 : 1.0
#                     lame = True              neg : pos    =      6.4 : 1.0
# ...

# %% [markdown]
# ## Using SKlearn classifiers within NLTK

# %%
from sklearn.svm import SVC
from nltk.classify.scikitlearn import SklearnClassifier

# %%
svc = SVC()
classifier_sklearn = SklearnClassifier(svc)

# %%
classifier_sklearn.train(training_data)
# Out:
# <SklearnClassifier(SVC())>

# %%
nltk.classify.accuracy(classifier_sklearn, testing_data)
# Out:
# 0.996

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier()
classifier_sklearn1 = SklearnClassifier(rfc)

# %%
classifier_sklearn1.train(training_data)
# Out:
# <SklearnClassifier(RandomForestClassifier())>

# %%
nltk.classify.accuracy(classifier_sklearn1, testing_data)
# Out:
# 1.0
